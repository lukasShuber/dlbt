# %%
from pathlib import Path

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import scipy.stats as ss
from tqdm import tqdm

RESOURCES_ROOT = Path.cwd().parent / 'resources'

# %% [markdown]
# ## Task family information
#
# - The full task family is a binary yes/no judgment over conjunctions of 4 binary latent dimensions:
#   - side: right / left
#   - transparency: transparent / opaque
#   - glossiness: glossy / matte
#   - size: large / small
# - The full task catalog is determined by those 4 dimensions and the conjunction arities:
#   - 8 one-way tasks
#   - 24 two-way conjunctions
#   - 32 three-way conjunctions
#   - 16 four-way conjunctions
#   - 80 tasks total
# - `task_id` is the comma-separated list of active factor values in fixed factor order:
#   - one-way example: `right`
#   - three-way example: `transparent,glossy,right`
# - Prompts are generated from the task spec rather than handwritten one by one:
#   - side-only example: `Is there an object on the **right**?`
#   - conjunction example: `Is there a **transparent**, **large** object on the **right**?`
#   - factor values appearing in the prompt are bolded
#
#
# In this run, the **complement** of the 22/80 task subset chosen by Lukas for run 0 was run (==58 tasks total).

# %% [markdown]
# ## Loading task metadata
#
# There are two task metadata tables in total. These are probably not necessary to analyze the behavioral data, but including them here for completeness.
#
# The first metadata table is `task-specs.csv`, which contains the prompt and generative rule that defines each task. Each row in the table corresponds to a single task. It includes the following columns:
# - `task_id`: the unique identifier for the task
# - `prompt`: the prompt shown to the subject in the instructions phase and on each trial.
#
# There are four columns describing the positive class for the task. If the value is NaN, that this factor is not considered in defining the class.
# - `transparency`: "transparent", "opaque", or NaN.
# - `glossiness`: "glossy", "matte", or NaN.
# - `size`: "small", "large", or NaN.
# - `side`: "left", "right", or NaN.

# %%
df_task_specs = pd.read_csv(RESOURCES_ROOT / 'task-specs.csv')
df_task_specs
# Out:
#                      task_id  \
# 0                transparent
# 1                     opaque
# 2                     glossy
# 3                      matte
# 4                      large
# ..                       ...
# 75  opaque,glossy,small,left
# 76  opaque,matte,large,right
# 77   opaque,matte,large,left
# 78  opaque,matte,small,right
# 79   opaque,matte,small,left
#
#                                                prompt transparency glossiness  \
# 0           Is there a rather **transparent** object?  transparent        NaN
# 1                Is there a rather **opaque** object?       opaque        NaN
# 2                Is there a rather **glossy** object?          NaN     glossy
# 3                 Is there a rather **matte** object?          NaN      matte
# 4                 Is there a rather **large** object?          NaN        NaN
# ..                                                ...          ...        ...
# 75  Is there a rather **opaque**, **glossy**, **sm...       opaque     glossy
# 76  Is there a rather **opaque**, **matte**, **lar...       opaque      matte
# 77  Is there a rather **opaque**, **matte**, **lar...       opaque      matte
# 78  Is there a rather **opaque**, **matte**, **sma...       opaque      matte
# 79  Is there a rather **opaque**, **matte**, **sma...       opaque      matte
#
#      size   side
# 0     NaN    NaN
# 1     NaN    NaN
# 2     NaN    NaN
# 3     NaN    NaN
# 4   large    NaN
# ..    ...    ...
# 75  small   left
# 76  large  right
# 77  large   left
# 78  small  right
# 79  small   left
#
# [80 rows x 6 columns]

# %% [markdown]
# The second metadata table is `task-label-vectors.csv`: each row corresponds to a single task. There is a `task_id` column; and the rest of he columns correspond to each of the 1000 images. The values are 0/1, indicating the correct response (no/yes) for each image in the task.

# %%
df_label_vectors = pd.read_csv(RESOURCES_ROOT / 'task-label-vectors.csv')
df_label_vectors
# Out:
#                      task_id  \
# 0                transparent
# 1                     opaque
# 2                     glossy
# 3                      matte
# 4                      large
# ..                       ...
# 75  opaque,glossy,small,left
# 76  opaque,matte,large,right
# 77   opaque,matte,large,left
# 78  opaque,matte,small,right
# 79   opaque,matte,small,left
#
#     000000_shdod_f04_yaw079_s083_lab065--041-+022_t036_gl097_xy+0006--0048_random.png  \
# 0                                                   0
# 1                                                   1
# 2                                                   1
# 3                                                   0
# 4                                                   1
# ..                                                ...
# 75                                                  0
# 76                                                  0
# 77                                                  0
# 78                                                  0
# 79                                                  0
#
#     000001_shoct_f02_yaw246_s083_lab046-+002--044_t073_gl031_xy-0125-+0205_random.png  \
# 0                                                   1
# 1                                                   0
# 2                                                   0
# 3                                                   1
# 4                                                   1
# ..                                                ...
# 75                                                  0
# 76                                                  0
# 77                                                  0
# 78                                                  0
# 79                                                  0
#
#     000002_shdod_f08_yaw290_s051_lab057--031-+041_t087_gl048_xy+0070--0148_random.png  \
# 0                                                   1
# 1                                                   0
# 2                                                   0
# 3                                                   1
# 4                                                   0
# ..                                                ...
# 75                                                  0
# 76                                                  0
# 77                                                  0
# 78                                                  0
# 79                                                  0
#
#     000003_shico_f00_yaw263_s055_lab072-+039-+026_t083_gl061_xy+0105-+0143_random.png  \
# 0                                                   1
# 1                                                   0
# 2                                                   1
# 3                                                   0
# 4                                                   0
# ..                                                ...
# 75                                                  0
# 76                                                  0
# 77                                                  0
# 78                                                  0
# 79                                                  0
#
#     000004_shico_f17_yaw183_s054_lab070-+023-+059_t008_gl045_xy-0131-+0234_random.png  \
# 0                                                   0
# 1                                                   1
# 2                                                   0
# 3                                                   1
# 4                                                   0
# ..                                                ...
# 75                                                  0
# 76                                                  0
# 77                                                  0
# 78                                                  0
# 79                                                  1
#
#     000005_shdod_f06_yaw296_s047_lab074--032--024_t024_gl032_xy-0028-+0048_random.png  \
# 0                                                   0
# 1                                                   1
# 2                                                   0
# 3                                                   1
# 4                                                   0
# ..                                                ...
# 75                                                  0
# 76                                                  0
# 77                                                  0
# 78                                                  0
# 79                                                  1
#
#     000006_shoct_f01_yaw141_s065_lab054-+068-+043_t092_gl090_xy+0188-+0212_random.png  \
# 0                                                   1
# 1                                                   0
# 2                                                   1
# 3                                                   0
# 4                                                   1
# ..                                                ...
# 75                                                  0
# 76                                                  0
# 77                                                  0
# 78                                                  0
# 79                                                  0
#
#     000007_shico_f08_yaw330_s088_lab044-+011-+048_t066_gl045_xy+0163--0040_random.png  \
# 0                                                   1
# 1                                                   0
# 2                                                   0
# 3                                                   1
# 4                                                   1
# ..                                                ...
# 75                                                  0
# 76                                                  0
# 77                                                  0
# 78                                                  0
# 79                                                  0
#
#     000008_shdod_f02_yaw053_s043_lab069-+003-+063_t082_gl033_xy-0191--0140_random.png  \
# 0                                                   1
# 1                                                   0
# 2                                                   0
# 3                                                   1
# 4                                                   0
# ..                                                ...
# 75                                                  0
# 76                                                  0
# 77                                                  0
# 78                                                  0
# 79                                                  0
#
#     ...  \
# 0   ...
# 1   ...
# 2   ...
# 3   ...
# 4   ...
# ..  ...
# 75  ...
# 76  ...
# 77  ...
# 78  ...
# 79  ...
#
#     000990_shdod_f04_yaw116_s077_lab036-+041-+048_t050_gl016_xy-0066--0042_random.png  \
# 0                                                   1
# 1                                                   0
# 2                                                   0
# 3                                                   1
# 4                                                   1
# ..                                                ...
# 75                                                  0
# 76                                                  0
# 77                                                  0
# 78                                                  0
# 79                                                  0
#
#     000991_shoct_f02_yaw260_s060_lab065-+009--049_t049_gl023_xy+0103-+0119_random.png  \
# 0                                                   0
# 1                                                   1
# 2                                                   0
# 3                                                   1
# 4                                                   0
# ..                                                ...
# 75                                                  0
# 76                                                  0
# 77                                                  0
# 78                                                  1
# 79                                                  0
#
#     000992_shdod_f06_yaw071_s081_lab066-+048-+009_t095_gl009_xy-0046--0165_random.png  \
# 0                                                   1
# 1                                                   0
# 2                                                   0
# 3                                                   1
# 4                                                   1
# ..                                                ...
# 75                                                  0
# 76                                                  0
# 77                                                  0
# 78                                                  0
# 79                                                  0
#
#     000993_shdod_f07_yaw144_s080_lab073-+060--039_t074_gl092_xy+0175-+0196_random.png  \
# 0                                                   1
# 1                                                   0
# 2                                                   1
# 3                                                   0
# 4                                                   1
# ..                                                ...
# 75                                                  0
# 76                                                  0
# 77                                                  0
# 78                                                  0
# 79                                                  0
#
#     000994_shdod_f03_yaw134_s043_lab055-+049--011_t084_gl040_xy+0158--0017_random.png  \
# 0                                                   1
# 1                                                   0
# 2                                                   0
# 3                                                   1
# 4                                                   0
# ..                                                ...
# 75                                                  0
# 76                                                  0
# 77                                                  0
# 78                                                  0
# 79                                                  0
#
#     000995_shoct_f03_yaw186_s060_lab055-+011-+049_t037_gl037_xy+0227-+0184_random.png  \
# 0                                                   0
# 1                                                   1
# 2                                                   0
# 3                                                   1
# 4                                                   0
# ..                                                ...
# 75                                                  0
# 76                                                  0
# 77                                                  0
# 78                                                  1
# 79                                                  0
#
#     000996_shoct_f07_yaw347_s052_lab056-+061--066_t023_gl051_xy-0036-+0056_random.png  \
# 0                                                   0
# 1                                                   1
# 2                                                   0
# 3                                                   1
# 4                                                   0
# ..                                                ...
# 75                                                  0
# 76                                                  0
# 77                                                  0
# 78                                                  0
# 79                                                  1
#
#     000997_shdod_f01_yaw308_s087_lab043-+056-+030_t042_gl099_xy+0236--0122_random.png  \
# 0                                                   0
# 1                                                   1
# 2                                                   1
# 3                                                   0
# 4                                                   1
# ..                                                ...
# 75                                                  0
# 76                                                  0
# 77                                                  0
# 78                                                  0
# 79                                                  0
#
#     000998_shico_f07_yaw263_s086_lab046-+057-+008_t073_gl022_xy-0245--0206_random.png  \
# 0                                                   1
# 1                                                   0
# 2                                                   0
# 3                                                   1
# 4                                                   1
# ..                                                ...
# 75                                                  0
# 76                                                  0
# 77                                                  0
# 78                                                  0
# 79                                                  0
#
#     000999_shoct_f05_yaw140_s046_lab042--027-+034_t031_gl035_xy-0164-+0105_random.png
# 0                                                   0
# 1                                                   1
# 2                                                   0
# 3                                                   1
# 4                                                   0
# ..                                                ...
# 75                                                  0
# 76                                                  0
# 77                                                  0
# 78                                                  0
# 79                                                  1
#
# [80 rows x 1001 columns]

# %% [markdown]
# ## Load behavioral data
#
# In the `dlbt-behavior.csv` table, rows are trials. The columns should be self-explanatory.
#
# Each trial sequence has the following format:
# - 10 warmup trials: exactly 5 positive and 5 negative non-probe images, without replacement
# - 120 post-warmup trials:
#     - 100 iid non-probe main-image draws with replacement and Bernoulli 0.5 / 0.5 class selection
#     - 16 probe-image trials, each probe image exactly once
#     - 4 catch trials total: 2 `press-yes.png` and 2 `press-no.png`
# - the 120 post-warmup trials are randomly permuted
# - `trial_kind` is one of `warmup`, `main`, `probe`, or `catch`

# %%
#df = pd.read_csv(RESOURCES_ROOT / 'dlbt-behavior-run2.csv')
df= pd.read_csv('/Users/mjl/PycharmProjects/dlbt-behavior/scripts/run2/mturk/production/dlbt-behavior.csv')
df
# Out:
#       trial_kind                                           stimulus  \
# 0         warmup  000611_shoct_f04_yaw343_s078_lab056--034-+040_...
# 1         warmup  000813_shoct_f03_yaw356_s072_lab072-+040--005_...
# 2         warmup  000166_shdod_f07_yaw018_s046_lab058--001-+047_...
# 3         warmup  000065_shico_f02_yaw117_s061_lab051-+058--031_...
# 4         warmup  000432_shdod_f07_yaw195_s045_lab049-+049--022_...
# ...          ...                                                ...
# 14945       main  000337_shoct_f07_yaw357_s046_lab038--007-+045_...
# 14946       main  000068_shdod_f02_yaw028_s060_lab074--041-+010_...
# 14947       main  000717_shoct_f02_yaw154_s063_lab071--041--006_...
# 14948       main  000799_shdod_f08_yaw264_s048_lab037--032-+030_...
# 14949       main  000616_shoct_f01_yaw111_s057_lab063-+010--044_...
#
#        stimulus_duration_msec correct_choice            sequence_id  \
# 0                         200             no  opaque,glossy,small:5
# 1                         200             no  opaque,glossy,small:5
# 2                         200            yes  opaque,glossy,small:5
# 3                         200            yes  opaque,glossy,small:5
# 4                         200             no  opaque,glossy,small:5
# ...                       ...            ...                    ...
# 14945                     200            yes          matte,small:2
# 14946                     200            yes          matte,small:2
# 14947                     200             no          matte,small:2
# 14948                     200             no          matte,small:2
# 14949                     200            yes          matte,small:2
#
#                                condition_id              task_id  trial  \
# 0      286da451-8e97-4e86-8cc0-0c8851dfde8b  opaque,glossy,small      0
# 1      4ef38be6-5f53-47b7-9b53-5390ff9d3f55  opaque,glossy,small      1
# 2      b53f53a1-b3bf-4847-a88b-a350858a9316  opaque,glossy,small      2
# 3      05442081-c0f3-411c-b151-fdf7d8d5b969  opaque,glossy,small      3
# 4      56e7d98b-536e-4e10-b42b-8984c84993bd  opaque,glossy,small      4
# ...                                     ...                  ...    ...
# 14945  021c1544-0857-4901-a16b-8517bca332cc          matte,small    125
# 14946  42c6d89f-0555-4a0a-83f4-6e6d35711e85          matte,small    126
# 14947  f46cf1f0-0c44-4344-b930-85c03d98cb24          matte,small    127
# 14948  a2ad19c5-ceea-45b9-821c-9625ceb886e1          matte,small    128
# 14949  ddf1eeea-5923-4923-8646-bc2c8a2e5acd          matte,small    129
#
#                                                   prompt choice  \
# 0      Is there a rather **opaque**, **glossy**, **sm...     no
# 1      Is there a rather **opaque**, **glossy**, **sm...     no
# 2      Is there a rather **opaque**, **glossy**, **sm...    yes
# 3      Is there a rather **opaque**, **glossy**, **sm...     no
# 4      Is there a rather **opaque**, **glossy**, **sm...    yes
# ...                                                  ...    ...
# 14945     Is there a rather **matte**, **small** object?    yes
# 14946     Is there a rather **matte**, **small** object?     no
# 14947     Is there a rather **matte**, **small** object?    yes
# 14948     Is there a rather **matte**, **small** object?    yes
# 14949     Is there a rather **matte**, **small** object?     no
#
#        reaction_time_msec  timestamp_start  \
# 0                    3340            58287
# 1                    2469            63848
# 2                    1697            67770
# 3                    2186            70841
# 4                    2490            74857
# ...                   ...              ...
# 14945                 884           560084
# 14946                 980           562338
# 14947                1372           565001
# 14948                 887           567857
# 14949                1360           570404
#
#                                            assignment_id  \
# 0      9b586489e61fa32242d434792a69cdeca02290a2289c5d...
# 1      9b586489e61fa32242d434792a69cdeca02290a2289c5d...
# 2      9b586489e61fa32242d434792a69cdeca02290a2289c5d...
# 3      9b586489e61fa32242d434792a69cdeca02290a2289c5d...
# 4      9b586489e61fa32242d434792a69cdeca02290a2289c5d...
# ...                                                  ...
# 14945  16edc9b506537d2eba2162e00eae06edbd3359d7f23860...
# 14946  16edc9b506537d2eba2162e00eae06edbd3359d7f23860...
# 14947  16edc9b506537d2eba2162e00eae06edbd3359d7f23860...
# 14948  16edc9b506537d2eba2162e00eae06edbd3359d7f23860...
# 14949  16edc9b506537d2eba2162e00eae06edbd3359d7f23860...
#
#                                                worker_id  \
# 0      079e1b75ba51c632736073339557925a0ed5e0f8922e19...
# 1      079e1b75ba51c632736073339557925a0ed5e0f8922e19...
# 2      079e1b75ba51c632736073339557925a0ed5e0f8922e19...
# 3      079e1b75ba51c632736073339557925a0ed5e0f8922e19...
# 4      079e1b75ba51c632736073339557925a0ed5e0f8922e19...
# ...                                                  ...
# 14945  71feb695b21198c3931ea21e305fed2e6a4a10e6504161...
# 14946  71feb695b21198c3931ea21e305fed2e6a4a10e6504161...
# 14947  71feb695b21198c3931ea21e305fed2e6a4a10e6504161...
# 14948  71feb695b21198c3931ea21e305fed2e6a4a10e6504161...
# 14949  71feb695b21198c3931ea21e305fed2e6a4a10e6504161...
#
#                                                   hit_id  perf
# 0      c6411962cd1cfab55ba8c2a7fb51daf18f31bd0a5ad407...     1
# 1      c6411962cd1cfab55ba8c2a7fb51daf18f31bd0a5ad407...     1
# 2      c6411962cd1cfab55ba8c2a7fb51daf18f31bd0a5ad407...     1
# 3      c6411962cd1cfab55ba8c2a7fb51daf18f31bd0a5ad407...     0
# 4      c6411962cd1cfab55ba8c2a7fb51daf18f31bd0a5ad407...     0
# ...                                                  ...   ...
# 14945  cd540ea4a0db91b7533c70714217b73e8aa5be6e23035c...     1
# 14946  cd540ea4a0db91b7533c70714217b73e8aa5be6e23035c...     0
# 14947  cd540ea4a0db91b7533c70714217b73e8aa5be6e23035c...     0
# 14948  cd540ea4a0db91b7533c70714217b73e8aa5be6e23035c...     0
# 14949  cd540ea4a0db91b7533c70714217b73e8aa5be6e23035c...     0
#
# [14950 rows x 16 columns]

# %% [markdown]
# # Exploratory data analyses
#
# Below, I execute some basic exploratory data analyses.

# %% [markdown]
# ## Number of unique participants

# %%
nunique_workers = len(set(df['worker_id']))

number_of_assignments_by_worker = df.groupby('worker_id')['assignment_id'].nunique()

plt.hist(number_of_assignments_by_worker, bins=np.arange(0.5, number_of_assignments_by_worker.max() + 1.5, 1))
plt.xlabel('Total trial sequences completed')
plt.ylabel('# participants')
plt.title(f"How many trial sequences did each participant complete?\n(n={nunique_workers} unique workers)")
plt.show()

# %% [markdown]
# ## Catch performances

# %%
df_catch = df.loc[df['trial_kind'] == 'catch']

catch_performances = df_catch.groupby('assignment_id')['perf'].mean()
plt.hist(catch_performances, bins=20)
plt.axvline(0.5, ls=':', color='gray')
plt.xlabel('Catch performance')
plt.ylabel('# participants')
plt.title("Distribution of catch trial performance across participants")
plt.show()

# %% [markdown]
# ## Warmup performance

# %%
df_warmup = df.loc[df['trial_kind'] == 'warmup']
plt.hist(df_warmup.groupby('assignment_id')['perf'].mean(), bins = np.linspace(0, 1, 10, endpoint=True))
plt.xlim([0, 1])
plt.axvline(0.5, ls=':', color='gray')
plt.xlabel('Warmup performance')
plt.ylabel('# participants')
plt.title("Distribution of warmup trial performance across participants")
plt.show()

# %% [markdown]
# ## Performance distribution

# %%
bins = np.linspace(0, 1, 51)
assignment_performances =df.groupby('assignment_id')['perf'].mean()
plt.hist(assignment_performances, bins = bins)
plt.axvline(0.5, ls=':', color='gray')
plt.xlabel('Average performance across all trials')
plt.ylabel('Assignment Count')

plt.show()

# %% [markdown]
# ## Learning curves

# %%
learning_curve = df.groupby('trial')['perf'].mean()
learning_curve_se = df.groupby('trial')['perf'].sem()


rt_curve = df.groupby('trial')['reaction_time_msec'].median()
#rt_curve_se = df.groupby('trial')['reaction_time_msec'].sem()

plt.errorbar(x = 1+np.arange(len(learning_curve)), y=learning_curve, yerr=learning_curve_se, marker = '.', lw=0, elinewidth=1, color='blue')
plt.xlabel('Trial')
plt.ylabel('Performance', color='blue')
plt.axhline(0.5, ls=':', color='gray')
plt.title("Participant- and task-averaged learning curve")
plt.ylim([None, 1])

plt.twinx()
plt.errorbar(x = 1+np.arange(len(rt_curve)), y=rt_curve, marker = '.', lw=1, elinewidth=1, color='orange')
plt.xlabel('Trial')
plt.ylabel('Reaction time (ms)', color='orange')


plt.show()

# %% [markdown]
# ## Reaction times

# %%
plt.hist(df['reaction_time_msec'], bins=100, range=(0, 5000))
plt.xlabel('Reaction time (ms)')
plt.ylabel('Count')
plt.title("Distribution of reaction times")
plt.xlim([0, None])
plt.show()

# %% [markdown]
# # Estimating probe matrices
#
# Below is the 'main' analysis for getting the probe matrix and training data for DLBT etc. It consists of two steps:
#
# 1. Assignment filtering, through the use of multiple filtering criteria:
#     - a catch performance criterion (participant must have received 4/4)
#     - a "main" performance criterion, on the 100 `main` trials. Participant must have received k/100 trials correct, where k is the 95th percentile (or higher) of the binomial distribution with n=100 and p=0.5. This is a lenient criterion that should exclude participants who are not performing above chance on the main trials.
# 2. Probe matrix estimation: for each probe condition (stimulus, task_id), we compute the mean performance across all observations that pass the filtering criteria. This gives us a 16 x 22 matrix of probe performances.

# %% [markdown]
# ## Assignment filtering

# %%
# Catch performance criterion
catch_performance_by_assignment = df.loc[df['trial_kind'] == 'catch'].groupby('assignment_id')['perf'].mean()
assignments_passing_catch = catch_performance_by_assignment[catch_performance_by_assignment == 1].index
print(f"{len(assignments_passing_catch)} / {len(catch_performance_by_assignment)} assignments passed the catch performance criterion.")
# Out:
# 93 / 115 assignments passed the catch performance criterion.

# %%
# Main performance criterion
main_performance_by_assignment = df.loc[df['trial_kind'] == 'main'].groupby('assignment_id')['perf'].mean()
main_performance_threshold = np.random.binomial(n=100, p=0.5, size=100000)
main_performance_threshold = np.percentile(main_performance_threshold, 95)
assignments_passing_main = main_performance_by_assignment[main_performance_by_assignment > main_performance_threshold / 100].index
print(f"{len(assignments_passing_main)} / {len(main_performance_by_assignment)} assignments passed the main performance criterion (threshold: greater than {main_performance_threshold} / 100).")
# Out:
# 38 / 115 assignments passed the main performance criterion (threshold: greater than 58.0 / 100).

# %%
df_filtered = df.loc[df['assignment_id'].isin(assignments_passing_catch) & df['assignment_id'].isin(assignments_passing_main)]
print(f"{len(df_filtered['assignment_id'].unique())} unique assignments passed both filtering criteria.")
# Out:
# 32 unique assignments passed both filtering criteria.

# %% [markdown]
# ## Probe matrix estimation

# %%
df_probe = df_filtered.loc[df_filtered['trial_kind'] == 'probe']

# %%
probe_matrix = df_probe.pivot_table('perf', index='stimulus', columns='task_id')
probe_matrix
# Out:
# task_id                                             glossy  glossy,large  \
# stimulus
# 000100_shoct_f02_yaw260_s074_lab059--040-+028_t...     1.0           1.0
# 000237_shoct_f07_yaw261_s043_lab045-+060--055_t...     1.0           1.0
# 000321_shoct_f04_yaw097_s073_lab046--044-+025_t...     1.0           0.0
# 000443_shdod_f00_yaw153_s048_lab062-+066-+003_t...     0.0           1.0
# 000477_shoct_f02_yaw254_s079_lab072--026--031_t...     1.0           1.0
# 000517_shdod_f08_yaw086_s080_lab047-+073-+022_t...     1.0           1.0
# 000613_shdod_f04_yaw120_s063_lab065--016--038_t...     1.0           1.0
# 000624_shico_f10_yaw196_s048_lab052-+012-+038_t...     0.0           0.0
# 000722_shoct_f04_yaw313_s085_lab070--028-+061_t...     0.0           0.0
# 000756_shoct_f04_yaw218_s077_lab075-+040--018_t...     1.0           0.0
# 000758_shico_f13_yaw247_s059_lab061-+042--010_t...     0.0           0.0
# 000795_shico_f19_yaw113_s046_lab053--020-+042_t...     0.0           1.0
# 000806_shdod_f06_yaw022_s073_lab052-+002-+042_t...     0.0           0.0
# 000878_shdod_f05_yaw245_s066_lab070--007--046_t...     1.0           0.0
# 000895_shdod_f04_yaw091_s049_lab050-+078-+002_t...     0.0           1.0
# 000927_shdod_f06_yaw169_s054_lab069-+046-+007_t...     0.0           1.0
#
# task_id                                             glossy,left  glossy,right  \
# stimulus
# 000100_shoct_f02_yaw260_s074_lab059--040-+028_t...     1.000000           1.0
# 000237_shoct_f07_yaw261_s043_lab045-+060--055_t...     0.428571           1.0
# 000321_shoct_f04_yaw097_s073_lab046--044-+025_t...     0.142857           1.0
# 000443_shdod_f00_yaw153_s048_lab062-+066-+003_t...     0.000000           1.0
# 000477_shoct_f02_yaw254_s079_lab072--026--031_t...     0.714286           1.0
# 000517_shdod_f08_yaw086_s080_lab047-+073-+022_t...     0.857143           1.0
# 000613_shdod_f04_yaw120_s063_lab065--016--038_t...     1.000000           1.0
# 000624_shico_f10_yaw196_s048_lab052-+012-+038_t...     1.000000           1.0
# 000722_shoct_f04_yaw313_s085_lab070--028-+061_t...     1.000000           0.0
# 000756_shoct_f04_yaw218_s077_lab075-+040--018_t...     1.000000           1.0
# 000758_shico_f13_yaw247_s059_lab061-+042--010_t...     1.000000           1.0
# 000795_shico_f19_yaw113_s046_lab053--020-+042_t...     1.000000           1.0
# 000806_shdod_f06_yaw022_s073_lab052-+002-+042_t...     0.285714           0.0
# 000878_shdod_f05_yaw245_s066_lab070--007--046_t...     1.000000           0.0
# 000895_shdod_f04_yaw091_s049_lab050-+078-+002_t...     1.000000           1.0
# 000927_shdod_f06_yaw169_s054_lab069-+046-+007_t...     1.000000           1.0
#
# task_id                                             large,left  matte  \
# stimulus
# 000100_shoct_f02_yaw260_s074_lab059--040-+028_t...         1.0    1.0
# 000237_shoct_f07_yaw261_s043_lab045-+060--055_t...         1.0    1.0
# 000321_shoct_f04_yaw097_s073_lab046--044-+025_t...         1.0    1.0
# 000443_shdod_f00_yaw153_s048_lab062-+066-+003_t...         1.0    0.5
# 000477_shoct_f02_yaw254_s079_lab072--026--031_t...         0.0    1.0
# 000517_shdod_f08_yaw086_s080_lab047-+073-+022_t...         1.0    0.0
# 000613_shdod_f04_yaw120_s063_lab065--016--038_t...         0.0    1.0
# 000624_shico_f10_yaw196_s048_lab052-+012-+038_t...         1.0    0.0
# 000722_shoct_f04_yaw313_s085_lab070--028-+061_t...         0.0    0.0
# 000756_shoct_f04_yaw218_s077_lab075-+040--018_t...         0.0    1.0
# 000758_shico_f13_yaw247_s059_lab061-+042--010_t...         1.0    1.0
# 000795_shico_f19_yaw113_s046_lab053--020-+042_t...         1.0    0.0
# 000806_shdod_f06_yaw022_s073_lab052-+002-+042_t...         1.0    1.0
# 000878_shdod_f05_yaw245_s066_lab070--007--046_t...         1.0    0.5
# 000895_shdod_f04_yaw091_s049_lab050-+078-+002_t...         1.0    1.0
# 000927_shdod_f06_yaw169_s054_lab069-+046-+007_t...         1.0    1.0
#
# task_id                                               opaque  opaque,glossy  \
# stimulus
# 000100_shoct_f02_yaw260_s074_lab059--040-+028_t...  1.000000       0.666667
# 000237_shoct_f07_yaw261_s043_lab045-+060--055_t...  0.666667       0.333333
# 000321_shoct_f04_yaw097_s073_lab046--044-+025_t...  0.666667       0.666667
# 000443_shdod_f00_yaw153_s048_lab062-+066-+003_t...  1.000000       0.333333
# 000477_shoct_f02_yaw254_s079_lab072--026--031_t...  0.000000       0.666667
# 000517_shdod_f08_yaw086_s080_lab047-+073-+022_t...  0.500000       0.666667
# 000613_shdod_f04_yaw120_s063_lab065--016--038_t...  0.166667       0.666667
# 000624_shico_f10_yaw196_s048_lab052-+012-+038_t...  0.833333       0.666667
# 000722_shoct_f04_yaw313_s085_lab070--028-+061_t...  0.833333       0.333333
# 000756_shoct_f04_yaw218_s077_lab075-+040--018_t...  0.833333       0.333333
# 000758_shico_f13_yaw247_s059_lab061-+042--010_t...  1.000000       1.000000
# 000795_shico_f19_yaw113_s046_lab053--020-+042_t...  0.666667       0.666667
# 000806_shdod_f06_yaw022_s073_lab052-+002-+042_t...  0.833333       0.333333
# 000878_shdod_f05_yaw245_s066_lab070--007--046_t...  0.333333       0.333333
# 000895_shdod_f04_yaw091_s049_lab050-+078-+002_t...  0.666667       0.666667
# 000927_shdod_f06_yaw169_s054_lab069-+046-+007_t...  0.833333       0.666667
#
# task_id                                             opaque,glossy,left  \
# stimulus
# 000100_shoct_f02_yaw260_s074_lab059--040-+028_t...                 0.0
# 000237_shoct_f07_yaw261_s043_lab045-+060--055_t...                 0.0
# 000321_shoct_f04_yaw097_s073_lab046--044-+025_t...                 0.0
# 000443_shdod_f00_yaw153_s048_lab062-+066-+003_t...                 1.0
# 000477_shoct_f02_yaw254_s079_lab072--026--031_t...                 1.0
# 000517_shdod_f08_yaw086_s080_lab047-+073-+022_t...                 1.0
# 000613_shdod_f04_yaw120_s063_lab065--016--038_t...                 1.0
# 000624_shico_f10_yaw196_s048_lab052-+012-+038_t...                 0.0
# 000722_shoct_f04_yaw313_s085_lab070--028-+061_t...                 1.0
# 000756_shoct_f04_yaw218_s077_lab075-+040--018_t...                 1.0
# 000758_shico_f13_yaw247_s059_lab061-+042--010_t...                 0.0
# 000795_shico_f19_yaw113_s046_lab053--020-+042_t...                 1.0
# 000806_shdod_f06_yaw022_s073_lab052-+002-+042_t...                 1.0
# 000878_shdod_f05_yaw245_s066_lab070--007--046_t...                 1.0
# 000895_shdod_f04_yaw091_s049_lab050-+078-+002_t...                 1.0
# 000927_shdod_f06_yaw169_s054_lab069-+046-+007_t...                 1.0
#
# task_id                                             opaque,glossy,small  \
# stimulus
# 000100_shoct_f02_yaw260_s074_lab059--040-+028_t...                  1.0
# 000237_shoct_f07_yaw261_s043_lab045-+060--055_t...                  0.0
# 000321_shoct_f04_yaw097_s073_lab046--044-+025_t...                  1.0
# 000443_shdod_f00_yaw153_s048_lab062-+066-+003_t...                  1.0
# 000477_shoct_f02_yaw254_s079_lab072--026--031_t...                  1.0
# 000517_shdod_f08_yaw086_s080_lab047-+073-+022_t...                  1.0
# 000613_shdod_f04_yaw120_s063_lab065--016--038_t...                  0.0
# 000624_shico_f10_yaw196_s048_lab052-+012-+038_t...                  1.0
# 000722_shoct_f04_yaw313_s085_lab070--028-+061_t...                  1.0
# 000756_shoct_f04_yaw218_s077_lab075-+040--018_t...                  1.0
# 000758_shico_f13_yaw247_s059_lab061-+042--010_t...                  0.0
# 000795_shico_f19_yaw113_s046_lab053--020-+042_t...                  0.0
# 000806_shdod_f06_yaw022_s073_lab052-+002-+042_t...                  1.0
# 000878_shdod_f05_yaw245_s066_lab070--007--046_t...                  1.0
# 000895_shdod_f04_yaw091_s049_lab050-+078-+002_t...                  0.0
# 000927_shdod_f06_yaw169_s054_lab069-+046-+007_t...                  0.0
#
# task_id                                             opaque,large  \
# stimulus
# 000100_shoct_f02_yaw260_s074_lab059--040-+028_t...           1.0
# 000237_shoct_f07_yaw261_s043_lab045-+060--055_t...           1.0
# 000321_shoct_f04_yaw097_s073_lab046--044-+025_t...           1.0
# 000443_shdod_f00_yaw153_s048_lab062-+066-+003_t...           0.0
# 000477_shoct_f02_yaw254_s079_lab072--026--031_t...           1.0
# 000517_shdod_f08_yaw086_s080_lab047-+073-+022_t...           1.0
# 000613_shdod_f04_yaw120_s063_lab065--016--038_t...           1.0
# 000624_shico_f10_yaw196_s048_lab052-+012-+038_t...           1.0
# 000722_shoct_f04_yaw313_s085_lab070--028-+061_t...           0.0
# 000756_shoct_f04_yaw218_s077_lab075-+040--018_t...           0.0
# 000758_shico_f13_yaw247_s059_lab061-+042--010_t...           1.0
# 000795_shico_f19_yaw113_s046_lab053--020-+042_t...           1.0
# 000806_shdod_f06_yaw022_s073_lab052-+002-+042_t...           0.0
# 000878_shdod_f05_yaw245_s066_lab070--007--046_t...           1.0
# 000895_shdod_f04_yaw091_s049_lab050-+078-+002_t...           1.0
# 000927_shdod_f06_yaw169_s054_lab069-+046-+007_t...           0.0
#
# task_id                                             transparent,large,right  \
# stimulus
# 000100_shoct_f02_yaw260_s074_lab059--040-+028_t...                      0.0
# 000237_shoct_f07_yaw261_s043_lab045-+060--055_t...                      1.0
# 000321_shoct_f04_yaw097_s073_lab046--044-+025_t...                      1.0
# 000443_shdod_f00_yaw153_s048_lab062-+066-+003_t...                      0.0
# 000477_shoct_f02_yaw254_s079_lab072--026--031_t...                      0.0
# 000517_shdod_f08_yaw086_s080_lab047-+073-+022_t...                      1.0
# 000613_shdod_f04_yaw120_s063_lab065--016--038_t...                      0.0
# 000624_shico_f10_yaw196_s048_lab052-+012-+038_t...                      1.0
# 000722_shoct_f04_yaw313_s085_lab070--028-+061_t...                      1.0
# 000756_shoct_f04_yaw218_s077_lab075-+040--018_t...                      1.0
# 000758_shico_f13_yaw247_s059_lab061-+042--010_t...                      0.0
# 000795_shico_f19_yaw113_s046_lab053--020-+042_t...                      1.0
# 000806_shdod_f06_yaw022_s073_lab052-+002-+042_t...                      1.0
# 000878_shdod_f05_yaw245_s066_lab070--007--046_t...                      1.0
# 000895_shdod_f04_yaw091_s049_lab050-+078-+002_t...                      1.0
# 000927_shdod_f06_yaw169_s054_lab069-+046-+007_t...                      1.0
#
# task_id                                             transparent,matte  \
# stimulus
# 000100_shoct_f02_yaw260_s074_lab059--040-+028_t...           0.333333
# 000237_shoct_f07_yaw261_s043_lab045-+060--055_t...           0.666667
# 000321_shoct_f04_yaw097_s073_lab046--044-+025_t...           1.000000
# 000443_shdod_f00_yaw153_s048_lab062-+066-+003_t...           1.000000
# 000477_shoct_f02_yaw254_s079_lab072--026--031_t...           0.333333
# 000517_shdod_f08_yaw086_s080_lab047-+073-+022_t...           0.666667
# 000613_shdod_f04_yaw120_s063_lab065--016--038_t...           0.333333
# 000624_shico_f10_yaw196_s048_lab052-+012-+038_t...           0.333333
# 000722_shoct_f04_yaw313_s085_lab070--028-+061_t...           1.000000
# 000756_shoct_f04_yaw218_s077_lab075-+040--018_t...           0.333333
# 000758_shico_f13_yaw247_s059_lab061-+042--010_t...           0.333333
# 000795_shico_f19_yaw113_s046_lab053--020-+042_t...           0.666667
# 000806_shdod_f06_yaw022_s073_lab052-+002-+042_t...           0.666667
# 000878_shdod_f05_yaw245_s066_lab070--007--046_t...           0.666667
# 000895_shdod_f04_yaw091_s049_lab050-+078-+002_t...           0.000000
# 000927_shdod_f06_yaw169_s054_lab069-+046-+007_t...           0.333333
#
# task_id                                             transparent,matte,large  \
# stimulus
# 000100_shoct_f02_yaw260_s074_lab059--040-+028_t...                      0.0
# 000237_shoct_f07_yaw261_s043_lab045-+060--055_t...                      1.0
# 000321_shoct_f04_yaw097_s073_lab046--044-+025_t...                      1.0
# 000443_shdod_f00_yaw153_s048_lab062-+066-+003_t...                      0.0
# 000477_shoct_f02_yaw254_s079_lab072--026--031_t...                      0.0
# 000517_shdod_f08_yaw086_s080_lab047-+073-+022_t...                      0.0
# 000613_shdod_f04_yaw120_s063_lab065--016--038_t...                      0.0
# 000624_shico_f10_yaw196_s048_lab052-+012-+038_t...                      1.0
# 000722_shoct_f04_yaw313_s085_lab070--028-+061_t...                      1.0
# 000756_shoct_f04_yaw218_s077_lab075-+040--018_t...                      1.0
# 000758_shico_f13_yaw247_s059_lab061-+042--010_t...                      1.0
# 000795_shico_f19_yaw113_s046_lab053--020-+042_t...                      1.0
# 000806_shdod_f06_yaw022_s073_lab052-+002-+042_t...                      1.0
# 000878_shdod_f05_yaw245_s066_lab070--007--046_t...                      0.0
# 000895_shdod_f04_yaw091_s049_lab050-+078-+002_t...                      0.0
# 000927_shdod_f06_yaw169_s054_lab069-+046-+007_t...                      1.0
#
# task_id                                             transparent,matte,small
# stimulus
# 000100_shoct_f02_yaw260_s074_lab059--040-+028_t...                      0.5
# 000237_shoct_f07_yaw261_s043_lab045-+060--055_t...                      1.0
# 000321_shoct_f04_yaw097_s073_lab046--044-+025_t...                      0.5
# 000443_shdod_f00_yaw153_s048_lab062-+066-+003_t...                      0.5
# 000477_shoct_f02_yaw254_s079_lab072--026--031_t...                      0.5
# 000517_shdod_f08_yaw086_s080_lab047-+073-+022_t...                      0.5
# 000613_shdod_f04_yaw120_s063_lab065--016--038_t...                      0.5
# 000624_shico_f10_yaw196_s048_lab052-+012-+038_t...                      1.0
# 000722_shoct_f04_yaw313_s085_lab070--028-+061_t...                      0.5
# 000756_shoct_f04_yaw218_s077_lab075-+040--018_t...                      0.5
# 000758_shico_f13_yaw247_s059_lab061-+042--010_t...                      0.5
# 000795_shico_f19_yaw113_s046_lab053--020-+042_t...                      0.5
# 000806_shdod_f06_yaw022_s073_lab052-+002-+042_t...                      0.5
# 000878_shdod_f05_yaw245_s066_lab070--007--046_t...                      1.0
# 000895_shdod_f04_yaw091_s049_lab050-+078-+002_t...                      0.0
# 000927_shdod_f06_yaw169_s054_lab069-+046-+007_t...                      0.5

# %%
plt.imshow(
    probe_matrix,
    vmin=0, vmax =1, cmap='coolwarm',
    aspect='auto'
)
plt.xlabel('task')
plt.ylabel('probe image')
plt.xticks(range(probe_matrix.shape[1]), rotation=90)
plt.colorbar()

plt.title("Performance on probe trials across stimuli and tasks")
plt.show()

# %% [markdown]
# ## Estimating the split-half reliability of the probe matrix
#
# Here, a probe condition is defined by the tuple `(stimulus, task_id)`. For each probe condition, we split all observations into two halves by random assignment of `assignment_id` to one of the halves. Then we compute the mean performance in each half, and compute the Pearson correlation coefficient across probe conditions between the two halves. We repeat this process over 100 splits, and report the mean and standard deviation over splits. This gives us an estimate of the reliability of the probe condition performances.
#
# Note that a given participant might show up in both halves; we are splitting by _assignment_id_, not by _worker_id_. This would happen when one participant performed multiple sequences for a single task.

# %%
# Check that each task has at least two unique assignments that pass the filtering criteria, so that we can do the split-half reliability analysis
import warnings
for task_id, df_task in df_filtered.groupby('task_id'):
    #print(f"Task {task_id} has {df_task['assignment_id'].nunique()} unique assignments that pass the filtering criteria.")
    if (df_task['assignment_id'].nunique()) < 2:
        print(f"Task \"{task_id}\" has fewer than 2 unique assignments that pass the filtering criteria. This task will be excluded from the split-half reliability analysis.")
# Out:
# Task "glossy" has fewer than 2 unique assignments that pass the filtering criteria. This task will be excluded from the split-half reliability analysis.
# Task "glossy,large" has fewer than 2 unique assignments that pass the filtering criteria. This task will be excluded from the split-half reliability analysis.
# Task "glossy,right" has fewer than 2 unique assignments that pass the filtering criteria. This task will be excluded from the split-half reliability analysis.
# Task "large,left" has fewer than 2 unique assignments that pass the filtering criteria. This task will be excluded from the split-half reliability analysis.
# Task "opaque,glossy,left" has fewer than 2 unique assignments that pass the filtering criteria. This task will be excluded from the split-half reliability analysis.
# Task "opaque,glossy,small" has fewer than 2 unique assignments that pass the filtering criteria. This task will be excluded from the split-half reliability analysis.
# Task "opaque,large" has fewer than 2 unique assignments that pass the filtering criteria. This task will be excluded from the split-half reliability analysis.
# Task "transparent,large,right" has fewer than 2 unique assignments that pass the filtering criteria. This task will be excluded from the split-half reliability analysis.
# Task "transparent,matte,large" has fewer than 2 unique assignments that pass the filtering criteria. This task will be excluded from the split-half reliability analysis.

# %%
plt.hist(df.groupby('task_id').apply(lambda df_task: df_task.loc[df_task['trial_kind'] == 'probe']['perf'].mean()))
plt.xlabel('Mean probe performance across all assignments')
plt.ylabel('Task count')
plt.title("Distribution of mean probe performance across tasks")
# Out:
# Text(0.5, 1.0, 'Distribution of mean probe performance across tasks')

# %%
num_splits = 100
reliabilities = []
for seed in tqdm(range(num_splits)):
    gen = np.random.default_rng(seed)
    half1_assignment_ids = []
    half2_assignment_ids = []


    for task_id, df_task in df_filtered.groupby('task_id'):
        # Randomly split assignments into two halves
        assignment_ids = list(df_task['assignment_id'].unique())
        gen.shuffle(assignment_ids)

        # Check if odd number:
        is_odd = len(assignment_ids) % 2 == 1

        # If odd, with 50-50 chance assign the extra assignment to either half:
        n_half1 = len(assignment_ids) // 2
        if is_odd and gen.random() < 0.5:
            n_half1 = len(assignment_ids) // 2 + 1

        half1_assignment_ids.extend(assignment_ids[:n_half1])
        half2_assignment_ids.extend(assignment_ids[n_half1:])



    df_half1 = df_filtered.loc[df_filtered['assignment_id'].isin(half1_assignment_ids) & (df_filtered['trial_kind'] == 'probe')]
    df_half2 = df_filtered.loc[df_filtered['assignment_id'].isin(half2_assignment_ids) & (df_filtered['trial_kind'] == 'probe')]

    probe_matrix_half1 = df_half1.pivot_table('perf', index='stimulus', columns='task_id')
    probe_matrix_half2 = df_half2.pivot_table('perf', index='stimulus', columns='task_id')
    common_tasks = list(set(probe_matrix_half1.columns) & set(probe_matrix_half2.columns))
    probe_matrix_half1 = probe_matrix_half1[common_tasks]
    probe_matrix_half2 = probe_matrix_half2[common_tasks]
    split_half_reliability = ss.pearsonr(probe_matrix_half1.values.flatten(), probe_matrix_half2.values.flatten())[0]

    reliabilities.append(split_half_reliability)
# Out:
# 100%|██████████| 100/100 [00:00<00:00, 242.65it/s]

# %%
print(f'Split-half reliability estimate of probe matrix: {np.mean(reliabilities):.2f}+-{np.std(reliabilities, ddof=1):.2f}', )
# Out:
# Split-half reliability estimate of probe matrix: 0.16+-0.07
